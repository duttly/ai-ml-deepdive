# %%
from micrograd.engine import Value

a = Value(2.0, label='a')
b = Value(-3.0, label='b')
c = Value(10.0, label='c')

e = a * b; e.label = 'e'
d = e + c; d.label = 'd'

print(f"d.data = {d.data}") 
# Look at how it remembers its history:
print(f"d was created by: {d._op}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from micrograd.engine import Value
#       2
# ----> 3 a = Value(2.0, label='a')
#       4 b = Value(-3.0, label='b')
#       5 c = Value(10.0, label='c')
#       6
#
# TypeError: Value.__init__() got an unexpected keyword argument 'label'
